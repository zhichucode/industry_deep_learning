# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as ms
ms.use('seaborn-muted')
# %matplotlib inline

# %%
import librosa
import librosa.display

# %%
wav_pathname = "/home/zzh/Sources/PYTHON/Audio/output.wav"

y, sr = librosa.load(wav_pathname, sr=441000)

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)
log_S = librosa.power_to_db(S)
plt.figure(figsize=(12,4))
librosa.display.specshow(log_S, sr=sr)
plt.title('MEL power spectrogram')
plt.colorbar(format='%+02.0f dB')
plt.tight_layout
# Out:
# /tmp/ipykernel_21933/2690670218.py:1: FutureWarning: Pass y=[ 0.04249577  0.04307574  0.04266286 ... -0.06327034 -0.04296632
#  -0.02456389] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)
# /home/zzh/anaconda3/envs/industry_DL3/lib/python3.9/site-packages/librosa/util/decorators.py:88: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   return f(*args, **kwargs)
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
print(S.shape)
# Out:
# (128, 4301)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_21933/1846175152.py in <module>
#       1 print(S.shape)
# ----> 2 S_rot = np.rot(S, 3)
#       3 print(S_rot.shape)
#
# ~/anaconda3/envs/industry_DL3/lib/python3.9/site-packages/numpy/__init__.py in __getattr__(attr)
#     311                 return Tester
#     312
# --> 313             raise AttributeError("module {!r} has no attribute "
#     314                                  "{!r}".format(__name__, attr))
#     315
#
# AttributeError: module 'numpy' has no attribute 'rot'

# %%
mfcc = librosa.feature.mfcc(S=log_S, n_mfcc=13)
delta_mfcc  = librosa.feature.delta(mfcc)
delta2_mfcc = librosa.feature.delta(mfcc, order=2)
plt.figure(figsize=(12, 6))
plt.subplot(3,1,1)
librosa.display.specshow(mfcc)
plt.ylabel('MFCC')
plt.colorbar()

plt.subplot(3,1,2)
librosa.display.specshow(delta_mfcc)
plt.ylabel('MFCC-$\Delta$')
plt.colorbar()

plt.subplot(3,1,3)
librosa.display.specshow(delta2_mfcc, sr=sr, x_axis='time')
plt.ylabel('MFCC-$\Delta^2$')
plt.colorbar()

plt.tight_layout()
M = np.vstack([mfcc, delta_mfcc, delta2_mfcc])

# %%
a = np.array([1,2,3])

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((1,2,3))
# Out:
# array([[[1., 1., 1.],
#         [1., 1., 1.]]])

# %%
np.empty(2)
# Out:
# array([6.92620932e-310, 6.92620965e-310])

# %%
np.arrage(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_21933/55584714.py in <module>
# ----> 1 np.arrage(4)
#
# ~/anaconda3/envs/industry_DL3/lib/python3.9/site-packages/numpy/__init__.py in __getattr__(attr)
#     311                 return Tester
#     312
# --> 313             raise AttributeError("module {!r} has no attribute "
#     314                                  "{!r}".format(__name__, attr))
#     315
#
# AttributeError: module 'numpy' has no attribute 'arrage'

# %%
# Out:
# '1.21.6'
